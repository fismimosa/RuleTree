# %%
import pandas as pd
import numpy as np
from glob import glob

# %%
glob("*.csv")
# Out:
# ['vertebral_column.csv',
#  'lrs.csv',
#  'algerian_forest_fires.csv',
#  'seeds.csv',
#  'ionosphere.csv',
#  'breast.csv',
#  'glass.csv',
#  'ecoli.csv',
#  'iris.csv']

# %%
# GIA PRESENTE

df = pd.read_csv('vertebral_column.csv')

print(df.shape)

df
# Out:
# (310, 7)
#      pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# 0           63.027817    22.552586              39.609117     40.475232
# 1           39.056951    10.060991              25.015378     28.995960
# 2           68.832021    22.218482              50.092194     46.613539
# 3           69.297008    24.652878              44.311238     44.644130
# 4           49.712859     9.652075              28.317406     40.060784
# ..                ...          ...                    ...           ...
# 305         47.903565    13.616688              36.000000     34.286877
# 306         53.936748    20.721496              29.220534     33.215251
# 307         61.446597    22.694968              46.170347     38.751628
# 308         45.252792     8.693157              41.583126     36.559635
# 309         33.841641     5.073991              36.641233     28.767649
#
#      pelvic_radius  degree_spondylolisthesis  label
# ...

# %%
# TROPPE COLONNE

df = pd.read_csv('lrs.csv')

print(df.shape)

df
# Out:
# (531, 101)
#      right_ascension  declination  scale_factor  blue_base_1  blue_base_2  \
# 0             12.073      -62.428  1.250000e-16         2498       2630.0
# 1             12.106      -62.987  2.970000e-16         1086       1241.0
# 2             12.123      -62.554  3.130000e-15          481        270.0
# 3             12.247      -67.683  1.730000e-15          191        232.0
# 4             12.360      -62.303  2.180000e-16         1401       1268.0
# ..               ...          ...           ...          ...          ...
# 526           23.819       62.732  2.220000e-16         1315       1495.0
# 527           23.827       61.526  1.250000e-15          238        280.0
# 528           23.881       48.360  5.740000e-16          577        568.0
# 529           23.902       70.526  4.120000e-16          995       1177.0
# 530           23.941      -56.854  4.840000e-16          562        640.0
#
# ...

# %%
# OK

df = pd.read_csv('algerian_forest_fires.csv')
df.drop(columns=['year'], inplace=True)

print(df.shape)

df
# Out:
# (243, 13)
#      day  month  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  \
# 0      1      6           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4  0.5
# 1      2      6           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9  0.4
# 2      3      6           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7  0.1
# 3      4      6           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7  0.0
# 4      5      6           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9  0.5
# ..   ...    ...          ...  ..  ..   ...   ...   ...   ...  ...   ...  ...
# 238   26      9           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5
# 239   27      9           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0
# 240   28      9           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2
# 241   29      9           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7
# 242   30      9           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5
#
#      label
# 0        1
# ...

# %%
# OK

df = pd.read_csv('seeds.csv')

print(df.shape)

df
# Out:
# (210, 8)
#         V1     V2      V3     V4     V5     V6     V7  label
# 0    15.26  14.84  0.8710  5.763  3.312  2.221  5.220      0
# 1    14.88  14.57  0.8811  5.554  3.333  1.018  4.956      0
# 2    14.29  14.09  0.9050  5.291  3.337  2.699  4.825      0
# 3    13.84  13.94  0.8955  5.324  3.379  2.259  4.805      0
# 4    16.14  14.99  0.9034  5.658  3.562  1.355  5.175      0
# ..     ...    ...     ...    ...    ...    ...    ...    ...
# 205  12.19  13.20  0.8783  5.137  2.981  3.631  4.870      2
# 206  11.23  12.88  0.8511  5.140  2.795  4.325  5.003      2
# 207  13.20  13.66  0.8883  5.236  3.232  8.315  5.056      2
# 208  11.84  13.21  0.8521  5.175  2.836  3.598  5.044      2
# 209  12.30  13.34  0.8684  5.243  2.974  5.637  5.063      2
#
# [210 rows x 8 columns]

# %%
# GIA PRESENTE

df = pd.read_csv('ionosphere.csv')

print(df.shape)

df
# Out:
# (351, 35)
#      0  1        2        3        4        5        6        7        8  \
# 0    1  0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000
# 1    1  0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000
# 2    1  0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965
# 3    1  0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000
# 4    1  0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152
# ..  .. ..      ...      ...      ...      ...      ...      ...      ...
# 346  1  0  0.83508  0.08298  0.73739 -0.14706  0.84349 -0.05567  0.90441
# 347  1  0  0.95113  0.00419  0.95183 -0.02723  0.93438 -0.01920  0.94590
# 348  1  0  0.94701 -0.00034  0.93207 -0.03227  0.95177 -0.03431  0.95584
# 349  1  0  0.90608 -0.01657  0.98122 -0.01989  0.95691 -0.03646  0.85746
# 350  1  0  0.84710  0.13533  0.73638 -0.06151  0.87873  0.08260  0.88928
#
#            9  ...       25       26       27       28       29       30  \
# ...

# %%
# GIA PRESENTE

df = pd.read_csv('breast.csv')

print(df.shape)

df
# Out:
# (569, 31)
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
# OK

df = pd.read_csv('glass.csv')

print(df.shape)

df
# Out:
# (214, 10)
#           RI     Na    Mg    Al     Si     K     Ca   Ba    Fe  label
# 0    1.51793  12.79  3.50  1.12  73.03  0.64   8.77  0.0  0.00      0
# 1    1.51643  12.16  3.52  1.35  72.89  0.57   8.53  0.0  0.00      5
# 2    1.51793  13.21  3.48  1.41  72.64  0.59   8.43  0.0  0.00      0
# 3    1.51299  14.40  1.74  1.54  74.55  0.00   7.59  0.0  0.00      4
# 4    1.53393  12.30  0.00  1.00  70.16  0.12  16.19  0.0  0.24      1
# ..       ...    ...   ...   ...    ...   ...    ...  ...   ...    ...
# 209  1.51610  13.42  3.40  1.22  72.69  0.59   8.32  0.0  0.00      5
# 210  1.51592  12.86  3.52  2.12  72.66  0.69   7.97  0.0  0.00      1
# 211  1.51613  13.92  3.52  1.25  72.88  0.37   7.94  0.0  0.14      1
# 212  1.51689  12.67  2.88  1.71  73.21  0.73   8.54  0.0  0.00      1
# 213  1.51852  14.09  2.19  1.66  72.67  0.00   9.32  0.0  0.00      4
#
# [214 rows x 10 columns]

# %%
# OK

df = pd.read_csv('ecoli.csv')

print(df.shape)

df
# Out:
# (336, 8)
#       mcg   gvh   lip  chg   aac  alm1  alm2  label
# 0    0.49  0.29  0.48  0.5  0.56  0.24  0.35      0
# 1    0.07  0.40  0.48  0.5  0.54  0.35  0.44      0
# 2    0.56  0.40  0.48  0.5  0.49  0.37  0.46      0
# 3    0.59  0.49  0.48  0.5  0.52  0.45  0.36      0
# 4    0.23  0.32  0.48  0.5  0.55  0.25  0.35      0
# ..    ...   ...   ...  ...   ...   ...   ...    ...
# 331  0.74  0.56  0.48  0.5  0.47  0.68  0.30      7
# 332  0.71  0.57  0.48  0.5  0.48  0.35  0.32      7
# 333  0.61  0.60  0.48  0.5  0.44  0.39  0.38      7
# 334  0.59  0.61  0.48  0.5  0.42  0.42  0.37      7
# 335  0.74  0.74  0.48  0.5  0.31  0.53  0.52      7
#
# [336 rows x 8 columns]

# %% [markdown]
# # Big Dataset

# %%
glob("big/*.csv")
# Out:
# ['big/house.csv',
#  'big/compas.csv',
#  'big/MagicTelescope.csv',
#  'big/steel_plates_faults.csv',
#  'big/road-safety.csv',
#  'big/covertype.csv',
#  'big/eye.csv',
#  'big/sylvine.csv',
#  'big/bank-marketing.csv',
#  'big/spambase.csv',
#  'big/pol.csv']

# %% [raw]
# ['big/house.csv',                  #già presente
#  'big/compas.csv',                 #già presente
#  'big/MagicTelescope.csv',         #ok
#  'big/steel_plates_faults.csv',    #troppe? 1941*28
#  'big/road-safety.csv',            #troppe? 2000*30
#  'big/covertype.csv',              #ok
#  'big/eye.csv',                    #ok? (2k*21)
#  'big/sylvine.csv',                #ok? (2k*21)
#  'big/bank-marketing.csv',         #ok 2k*8
#  'big/spambase.csv',               #troppo grande 4601*58
#  'big/pol.csv'].                   #troppo grande 2k*27

# %%
# OK

df = pd.read_csv('big/eye.csv')

print(df.shape)

df
# Out:
# (2000, 21)
#       lineNo  assgNo  prevFixDur  firstfixDur  firstPassFixDur  nextFixDur  \
# 0     3703.0   116.0       199.0        239.0            477.0       139.0
# 1     2889.0    88.0         0.0        179.0            179.0       199.0
# 2     9387.0   291.0       139.0        119.0            119.0       219.0
# 3     3498.0   108.0       199.0        179.0            179.0       119.0
# 4     5520.0   165.0       139.0        179.0            318.0       179.0
# ...      ...     ...         ...          ...              ...         ...
# 1995  7180.0   219.0       219.0        139.0            139.0       179.0
# 1996  9743.0   300.0       179.0        179.0            179.0       139.0
# 1997  3873.0   124.0       278.0         80.0            240.0        99.0
# 1998   466.0    14.0       179.0        179.0            179.0       278.0
# 1999  7166.0   219.0       179.0         80.0            219.0        80.0
#
# ...
